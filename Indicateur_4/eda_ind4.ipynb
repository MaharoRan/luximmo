# %% [markdown]
# # EDA Indicateur 4

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/amenagements-cyclables.parquet")
df.head(10)
# Out:
#       osm_id                                    nom  \
# 0  693056491                       Rue des Pyrénées
# 1  693110778                                    NaN
# 2  694004567                     Boulevard de Bercy
# 3  694769031                         Rue du Théâtre
# 4  696354695                       Avenue Daumesnil
# 5  697939001                   Place de la Bastille
# 6  698892814                        Rue Charlemagne
# 7  700088130  Route de la Ceinture du Lac Daumesnil
# 8  701883670                     Route des Tribunes
# 9  702192838                   Route de la Pyramide
#
#                     amenagement cote_amenagement sens     surface  \
# 0  couloir bus ouvert aux vélos            droit  NaN    Asphalte
# 1                piste cyclable            droit  NaN  Pavé lisse
# 2                bande cyclable            droit  NaN    Asphalte
# 3                piste cyclable            droit  NaN         NaN
# ...

# %%
import pandas as pd

df = pd.read_csv(r"./raw/emplacement-des-gares-idf.csv", sep=";")
df.head(10)
# Out:
#                                 Geo Point  \
# 0  48.667901961049886, 2.5475480458143664
# 1  48.613427913594734, 2.4729336504587436
# 2  48.843772576851464, 2.3739164698064985
# 3    49.03318276903128, 2.478033365115082
# 4   49.13828637527201, 2.4901789854211955
# 5   49.099586939193706, 2.525531713992054
# 6   48.99377714689272, 2.4161874889269837
# 7  48.531501986486845, 2.3705184977367075
# 8  49.136000564590994, 2.2426777767781676
# 9     48.966326544842126, 2.3165820711557
#
#                                            Geo Shape  OBJECTID_1  gares_id  \
# 0  {"coordinates": [2.547548045814366, 48.6679019...          91       196
# 1  {"coordinates": [2.472933650458744, 48.6134279...          94       207
# 2  {"coordinates": [2.373916469806499, 48.8437725...         128       307
# 3  {"coordinates": [2.478033365115082, 49.0331827...         190       452
# 4  {"coordinates": [2.490178985421196, 49.1382863...         242       957
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/plan de voirie.parquet")
df.head(10)
# Out:
#    OBJECTID NUM_PAVE  IGDS_LEVEL  LIB_LEVEL LIB_CLASSE  \
# 0    201825     133G          21  TRANSPORT        NaN
# 1    201854     151G          21  TRANSPORT        NaN
# 2    201894     193J          21  TRANSPORT        NaN
# 3    201897     154C          21  TRANSPORT        NaN
# 4    201903     173B          21  TRANSPORT        NaN
# 5    201904     173B          21  TRANSPORT        NaN
# 6    201912     142C          21  TRANSPORT        NaN
# 7    201922     184B          21  TRANSPORT        NaN
# 8    201929     184B          21  TRANSPORT        NaN
# 9    201944     163E          21  TRANSPORT        NaN
#
#                                            geo_shape  \
# 0  {"coordinates": [[2.355696017000305, 48.820648...
# 1  {"coordinates": [[2.2925539116883042, 48.83081...
# 2  {"coordinates": [[2.405373885476651, 48.877921...
# 3  {"coordinates": [[2.279349104077107, 48.835857...
# 4  {"coordinates": [[2.3126839621584003, 48.89402...
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/velib-emplacement-des-stations.parquet")
df.head(10)
# Out:
#   stationcode                                 name  capacity  \
# 0       10115                   Granges aux Belles        27
# 1       12128           Pyramide - Ecole du Breuil        34
# 2        8028     Arsène Houssaye - Champs-Elysées         0
# 3       16136  Théophile Gautier - François Millet        30
# 4       19022                      Marché Secrétan        26
# 5       21104         Madame de Sanzillon - Mozart        22
# 6       51004          Général Delambre - Prebuard        29
# 7       12009                  Charenton - Diderot        18
# 8       19008              Flandre - Alphonse Karr        26
# 9       12027               Montgallet - Charenton        16
#
#                                      coordonnees_geo station_opening_hours
# 0  b'\x01\x01\x00\x00\x00\xec\x97\x06I\xd6\xf1\x0...                   NaN
# 1  b'\x01\x01\x00\x00\x00\x01\x00\x00(d\xab\x03@\...                   NaN
# ...
