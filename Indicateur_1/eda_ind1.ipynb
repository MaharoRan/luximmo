# %% [markdown]
# # EDA Indicateur 1

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/eclairage-public.parquet")
df.head(10)
# Out:
#   cod_ouvrag    foyer        lib_domain  lib_ouvrag observatio  \
# 0     801677  0109124  Eclairage Public  Projecteur      +9761
# 1     801679  0109137  Eclairage Public  Projecteur      +9763
# 2     801683  0109121  Eclairage Public  Projecteur      +9767
# 3     802025  0109752  Eclairage Public         Sol      +9791
# 4     802034  0109734  Eclairage Public         Sol      +9800
# 5     802038  0109726  Eclairage Public         Sol      +9804
# 6     801778  0109194  Eclairage Public  Projecteur      +9831
# 7     801799  0109219  Eclairage Public  Projecteur      +9846
# 8     801799  0109218  Eclairage Public  Projecteur      +9846
# 9     802491  0109439  Eclairage Public  Projecteur      +9853
#
#           posx_ouvra         posy_ouvra             x_wgs84  \
# 0  652176.0385610145  6862624.529103298  2.3481407998068904
# 1  652162.4615239749   6862622.18956036  2.3479560112423616
# 2  652151.0983611441   6862597.60658201   2.347803901536252
# ...

# %%
df = pd.read_parquet(r"./raw/ilots-de-fraicheur-equipements-activites.parquet")
df.head(10)
# Out:
#   identifiant id_dicom                                     nom  \
# 0        LC35    19465          Eglise Saint-François de Sales
# 1        OM50      NaN  KIOSQUE A MUSIQUE SQUARE JEAN CHERIOUX
# 2        LC96    19484           Eglise Saint-Julien Le Pauvre
# 3       LC100      NaN      Cathedrale Saint-Vladimir Le Grand
# 4        MU74      NaN                         Maison du Japon
# 5         MA5   (3717)                            MAIRIE DU 5E
# 6        LC53      NaN     Eglise de l'Hôpital du Val de Grace
# 7        MU10      NaN                         Musée du Louvre
# 8        LC12      NaN   Eglise Armenienne Saint-Jean Baptiste
# 9        MU25      NaN          Musée National Guimet (annexe)
#
#                       type payant                        adresse  \
# 0           Lieux de culte    Non                 15  RUE AMPERE
# 1         Ombrière pérenne    Non          260  RUE DE VAUGIRARD
# 2           Lieux de culte    Non  1  RUE SAINT-JULIEN LE PAUVRE
# ...

# %%
df = pd.read_parquet(r"./raw/ilots-de-fraicheur-espaces-verts-frais.parquet")
df.head(10)
# Out:
#   identifiant  nsq_espace_vert  \
# 0      ID1598          12950.0
# 1       ID827              NaN
# 2       ID681            147.0
# 3       ID733            664.0
# 4      ID1211          10045.0
# 5       ID745            374.0
# 6       ID843            827.0
# 7       ID910          11513.0
# 8       ID835          10045.0
# 9       ID163            849.0
#
#                                                  nom  \
# 0                   JARDINIERES DU BOULEVARD BOURDON
# 1                Jardin de la place Mohamed Bouazizi
# 2  MAIL PIERRE DESPROGES DIT TROTTOIR PIERRE DESP...
# 3                                 MAIL MARCEL ACHARD
# 4                                   Bois de Boulogne
# 5                          PROMENADE D'AUSTRALIE 15E
# 6                       SQUARE RESTIF DE LA BRETONNE
# 7                                PARC DE LA VILLETTE
# 8                              La Garde Républicaine
# 9               JARDINET DE LA PLACE RAOUL FOLLEREAU
#
# ...

# %%
df = pd.read_parquet(r"./raw/les-arbres.parquet")
df.head(10)
# Out:
#    idbase typeemplacement domanialite   arrondissement complementadresse  \
# 0  126117           Arbre      Jardin  PARIS 20E ARRDT               NaN
# 1  141306           Arbre   CIMETIERE  PARIS 15E ARRDT               NaN
# 2  250335           Arbre  Alignement  PARIS 19E ARRDT               NaN
# 3  278516           Arbre  Alignement  PARIS 13E ARRDT               NaN
# 4  216594           Arbre  Alignement  PARIS 19E ARRDT                15
# 5  223855           Arbre  Alignement  PARIS 11E ARRDT               116
# 6  106474           Arbre      Jardin   PARIS 7E ARRDT         Canton 10
# 7  266201           Arbre  Alignement  PARIS 15E ARRDT               111
# 8  157556           Arbre   CIMETIERE     VAL-DE-MARNE               NaN
# 9  105989           Arbre      Jardin  PARIS 20E ARRDT               NaN
#
#                                              adresse idemplacement  \
# 0  JARDIN DE LA GARE DE CHARONNE / 59 BOULEVARD D...     000103036
# ...

# %%
df = pd.read_parquet(r"./raw/sanisettesparis.parquet")
df.head(10)
# Out:
#         type        statut                      adresse arrondissement  \
# 0         WC  Hors service       2 quai de l archeveche          75004
# 1  Sanisette    En service          36 bd de sebastopol          75004
# 2  Sanisette    En service  10 avenue de l observatoire          75006
# 3  Sanisette    En service       93b bd du montparnasse          75006
# 4  Sanisette    En service      135b bd du montparnasse          75006
# 5  Sanisette    En service                 2t pl joffre          75007
# 6  Sanisette    En service               1 av de verdun          75010
# 7  Sanisette    En service        81b bd de la villette          75010
# 8  Sanisette    En service             96 rue oberkampf          75011
# 9         WC    En service        30 rue du rendez-vous          75012
#
#             horaire acces_pmr relais_bebe  \
# 0  Horaires du parc       Non         Non
# 1     06h00 - 22h00       Oui         Non
# 2  Horaires du parc       Oui         Non
# ...

# %%
df = pd.read_parquet(r"./raw/zones-touristiques-internationales.parquet")
df.head(10)
# Out:
#                        name          type            _timestamp    _uid  \
# 0    Saint-Honoré - Vendôme      boundary  2016-07-26T17:22:16Z  158826
# 1                Montmartre      boundary  2016-07-26T16:15:57Z  158826
# 2                Olympiades      boundary  2016-07-26T16:39:02Z  158826
# 3                 Le Marais  multipolygon  2016-07-26T15:30:19Z  158826
# 4    Rennes - Saint-Sulpice      boundary  2016-07-26T17:30:29Z  158826
# 5            Maillot-Ternes      boundary  2016-07-26T15:53:40Z  158826
# 6             Saint-Germain      boundary  2016-07-26T17:30:29Z  158826
# 7                 Haussmann  multipolygon  2016-07-26T17:22:16Z  158826
# 8                Les Halles      boundary  2016-07-26T17:22:16Z  158826
# 9  Champs-Elysées Montaigne      boundary  2016-07-26T14:10:50Z  158826
#
#                  source   _user _version      boundary _changeset  \
# 0  JORFTEXT000031223603  cquest        1  tourist_zone   41043008
# ...
