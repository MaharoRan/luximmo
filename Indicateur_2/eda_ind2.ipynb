# %% [markdown]
# # EDA Indicateur 2

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/ilots-de-fraicheur-espaces-verts-frais.parquet")
df.head(10)
# Out:
#   identifiant  nsq_espace_vert  \
# 0      ID1598          12950.0
# 1       ID827              NaN
# 2       ID681            147.0
# 3       ID733            664.0
# 4      ID1211          10045.0
# 5       ID745            374.0
# 6       ID843            827.0
# 7       ID910          11513.0
# 8       ID835          10045.0
# 9       ID163            849.0
#
#                                                  nom  \
# 0                   JARDINIERES DU BOULEVARD BOURDON
# 1                Jardin de la place Mohamed Bouazizi
# 2  MAIL PIERRE DESPROGES DIT TROTTOIR PIERRE DESP...
# 3                                 MAIL MARCEL ACHARD
# 4                                   Bois de Boulogne
# 5                          PROMENADE D'AUSTRALIE 15E
# 6                       SQUARE RESTIF DE LA BRETONNE
# 7                                PARC DE LA VILLETTE
# 8                              La Garde Républicaine
# 9               JARDINET DE LA PLACE RAOUL FOLLEREAU
#
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/les-arbres.parquet")
df.head(10)
# Out:
#    idbase typeemplacement domanialite   arrondissement complementadresse  \
# 0  126117           Arbre      Jardin  PARIS 20E ARRDT               NaN
# 1  141306           Arbre   CIMETIERE  PARIS 15E ARRDT               NaN
# 2  250335           Arbre  Alignement  PARIS 19E ARRDT               NaN
# 3  278516           Arbre  Alignement  PARIS 13E ARRDT               NaN
# 4  216594           Arbre  Alignement  PARIS 19E ARRDT                15
# 5  223855           Arbre  Alignement  PARIS 11E ARRDT               116
# 6  106474           Arbre      Jardin   PARIS 7E ARRDT         Canton 10
# 7  266201           Arbre  Alignement  PARIS 15E ARRDT               111
# 8  157556           Arbre   CIMETIERE     VAL-DE-MARNE               NaN
# 9  105989           Arbre      Jardin  PARIS 20E ARRDT               NaN
#
#                                              adresse idemplacement  \
# 0  JARDIN DE LA GARE DE CHARONNE / 59 BOULEVARD D...     000103036
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/lieux-de-tournage-a-paris.parquet")
df.head(10)
# Out:
#      id_lieu annee_tournage type_tournage  \
# 0  2016-1939     2016-01-01      Série TV
# 1  2016-1495     2016-01-01  Long métrage
# 2  2020-1082     2020-01-01  Long métrage
# 3  2016-2623     2016-01-01  Long métrage
# 4   2019-878     2019-01-01  Long métrage
# 5   2019-956     2019-01-01      Série TV
# 6  2021-1742     2021-01-01      Série TV
# 7   2017-549     2017-01-01      Série TV
# 8  2017-1618     2017-01-01  Long métrage
# 9   2017-595     2017-01-01      Série TV
#
#                                       nom_tournage  \
# 0                            LES HOMMES DE L'OMBRE
# 1                                     MAMAN A TORT
# 2                             STELLA EST AMOUREUSE
# 3                                       THE ESCAPE
# 4                                   PARENT D'ELEVE
# 5  FIND ME IN PARIS Saison 3( LENA REVE D'ETOILES)
# 6                                    SOUS CONTROLE
# 7                                       Baron noir
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/liste_des_associations_parisiennes.parquet")
df.head(10)
# Out:
#                                    pr_nom_statutaire  cp_adresse_code_postal  \
# 0                                     YOGA ET CETERA                 75018.0
# 1                                   CHOEUR · PRENDRE                 75015.0
# 2                                 COMPAGNIE VARSORIO                 75019.0
# 3  COMITE REGIONAL DE L'ACADEMIE DE PARIS DE LA F...                 75014.0
# 4       ERSR (ECOLE DE LA RESPIRATION SANDRA-ROMOND)                 75020.0
# 5                                  PARI MULTI-GLISSE                 75012.0
# 6                                  JUDO FRANCE PARIS                 75019.0
# 7                                 COMPAGNIE VARSORIO                 75019.0
# 8                         ECOLE PARISIENNE DE KARATE                 75009.0
# 9       COMIT DPARTEMENTAL DE SPLOLOGIE DE PARIS                 75014.0
#
#   cp_adresse_ville sa_secteur_d_activit_1 sa_secteur_d_activit_2  \
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/plan de voirie.parquet")
df.head(10)
# Out:
#    OBJECTID NUM_PAVE  IGDS_LEVEL  LIB_LEVEL LIB_CLASSE  \
# 0    201825     133G          21  TRANSPORT        NaN
# 1    201854     151G          21  TRANSPORT        NaN
# 2    201894     193J          21  TRANSPORT        NaN
# 3    201897     154C          21  TRANSPORT        NaN
# 4    201903     173B          21  TRANSPORT        NaN
# 5    201904     173B          21  TRANSPORT        NaN
# 6    201912     142C          21  TRANSPORT        NaN
# 7    201922     184B          21  TRANSPORT        NaN
# 8    201929     184B          21  TRANSPORT        NaN
# 9    201944     163E          21  TRANSPORT        NaN
#
#                                            geo_shape  \
# 0  {"coordinates": [[2.355696017000305, 48.820648...
# 1  {"coordinates": [[2.2925539116883042, 48.83081...
# 2  {"coordinates": [[2.405373885476651, 48.877921...
# 3  {"coordinates": [[2.279349104077107, 48.835857...
# 4  {"coordinates": [[2.3126839621584003, 48.89402...
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/que-faire-a-paris.parquet")
df.head(10)
# Out:
#       id  event_id                                                url  \
# 0  11022      4287  https://www.paris.fr/evenements/les-balades-gu...
# 1  15396      8604  https://www.paris.fr/evenements/paroles-d-adul...
# 2  53785     39683  https://www.paris.fr/evenements/montmartre-enc...
# 3  11018      4283  https://www.paris.fr/evenements/la-folle-et-in...
# 4  66412     51122  https://www.paris.fr/evenements/jazzdedemain-l...
# 5  66789     51437  https://www.paris.fr/evenements/paris-street-a...
# 6  66827     51475  https://www.paris.fr/evenements/le-cambrioleur...
# 7  87381     67216  https://www.paris.fr/evenements/l-echo-des-sai...
# 8  90308     69512  https://www.paris.fr/evenements/paris-sport-pr...
# 9  48826     34970  https://www.paris.fr/evenements/paris-sport-pr...
#
#                                                title  \
# 0     Les balades guidées virtuelles d'Explore Paris
# 1  Paroles d’adultes, regards d’enfants : aborder...
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/zones-touristiques-internationales.parquet")
df.head(10)
# Out:
#                        name          type            _timestamp    _uid  \
# 0    Saint-Honoré - Vendôme      boundary  2016-07-26T17:22:16Z  158826
# 1                Montmartre      boundary  2016-07-26T16:15:57Z  158826
# 2                Olympiades      boundary  2016-07-26T16:39:02Z  158826
# 3                 Le Marais  multipolygon  2016-07-26T15:30:19Z  158826
# 4    Rennes - Saint-Sulpice      boundary  2016-07-26T17:30:29Z  158826
# 5            Maillot-Ternes      boundary  2016-07-26T15:53:40Z  158826
# 6             Saint-Germain      boundary  2016-07-26T17:30:29Z  158826
# 7                 Haussmann  multipolygon  2016-07-26T17:22:16Z  158826
# 8                Les Halles      boundary  2016-07-26T17:22:16Z  158826
# 9  Champs-Elysées Montaigne      boundary  2016-07-26T14:10:50Z  158826
#
#                  source   _user _version      boundary _changeset  \
# 0  JORFTEXT000031223603  cquest        1  tourist_zone   41043008
# ...
