# %% [markdown]
# # EDA Indicateur 3

# %%
import pandas as pd

df = pd.read_csv(r"./raw/carte-des-points-daccueil-police-a-paris.csv", sep=";")
df.head(10)
# Out:
#   ardt                       service                           adresse  \
# 0  12e             DPGP Gare de Lyon         80, allée de Bercy Voie N
# 1   7e          Commissariat central                     9, rue Fabert
# 2  16e          Commissariat central                  62 avenue Mozart
# 3  19e                 BDEP Amérique          12, rue Augustin Thierry
# 4   3e          Commissariat central             4 bis, 6 rue aux Ours
# 5   6e                          SAIP                 12, rue Jean Bart
# 6  1er                BDEP - Vendôme  45, place du Marché-Saint-Honoré
# 7  16e                          SAIP         75, rue de la Faisanderie
# 8  16e                  BDEP Auteuil           74, rue Chardon Lagache
# 9  12e  Commissariat central et SAIP              80, avenue Daumesnil
#
#         téléphone                         horaires  \
# 0  01 53 02 94 00  tous les jours de 6 h30 à 22h40
# 1  01 44 18 69 07                     7j/7  24h/24
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/etablissements-scolaires-ecoles-elementaires.parquet")
df.head(10)
# Out:
#                                  id_projet                   libelle  \
# 0  ELEMENTAIRES (année scolaire 2022/2023)           LITTRE (6) ELEM
# 1  ELEMENTAIRES (année scolaire 2022/2023)       CHAMPAGNE (17) POLY
# 2  ELEMENTAIRES (année scolaire 2021/2022)  ALAIN-FOURNIER ( 5) ELEM
# 3  ELEMENTAIRES (année scolaire 2021/2022)  PIERRE FONCIN (8) ELEM A
# 4  ELEMENTAIRES (année scolaire 2021/2022)      CHARENTON (315) ELEM
# 5  ELEMENTAIRES (année scolaire 2021/2022)           ARAGO (30) ELEM
# 6  ELEMENTAIRES (année scolaire 2021/2022)            ORAN (18) ELEM
# 7  ELEMENTAIRES (année scolaire 2021/2022)     MICHEL ANGE (51) ELEM
# 8  ELEMENTAIRES (année scolaire 2022/2023)   ETIENNE DOLET (31) ELEM
# 9  ELEMENTAIRES (année scolaire 2021/2022)        PYRENEES (97) ELEM
#
#                    adresse arr_libelle  arr_insee annee_scol   type_etabl  \
# 0             6 RUE LITTRE   6ème Ardt      75106  2022-2023  Elémentaire
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/hopitaux.parquet")
df.head(10)
# Out:
#    finess_et  finess_ej                          raison_sociale  \
# 0  950032722  950110080         HOPITAL DE JOUR FRANCOIS VILLON
# 1  780000345  780110078        CH DE VERSAILLES-HOPITAL RICHAUD
# 2  920025152  920804465         CMP 92I05 ENFANTS "CHAVISÈVRES"
# 3  920690278  920718202           HOPITAL DE JOUR "LES LIERRES"
# 4  920810603  950140012            CMP ADULTES 92G02 (RABELAIS)
# 5  920814027  940140049            POLYCLINIQUE COUTURIER 92G18
# 6  910002286  910140029               APPARTEMENT THERAPEUTIQUE
# 7  750000507  750040628                        CENTRE PARIS SUD
# 8  750007619  750720674  HOP DE JOUR CEREP (U.S.I.S. ET E.P.I.)
# 9  750802761  910140011                    CMP ADULTES SALNEUVE
#
#                      raison_sociale_entite_juridique adresse_administrative_1  \
# 0                    HOPITAL DE JOUR FRANCOIS VILLON                      NaN
# 1   CENTRE HOSPITALIER DE VERSAILLES-HOPITAL RICHAUD                      NaN
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/les_bureaux_de_poste_et_agences_postales_en_idf.parquet")
df.head(10)
# Out:
#               libelle_du_site   caracteristique_du_site  \
# 0   FRANCONVILLE GUYON APC AP  Agence postale communale
# 1            CERGY SME LPR RP              Relais poste
# 2        SARCELLES SABLONS AP  Agence postale communale
# 3  PERSAN BEAUMONT SNCF RELAY          Point partenaire
# 4                  ANDILLY BP           Bureau de Poste
# 5          AUVERS SUR OISE BP           Bureau de Poste
# 6               GOUSSAINVILLE           Bureau de Poste
# 7         MARINES LE VEXIN BP           Bureau de Poste
# 8               MONTLIGNON BP           Bureau de Poste
# 9                  PRESLES BP           Bureau de Poste
#
#                                adresse                  complement_d_adresse  \
# 0  CENTRE COMMERCIAL AVENUE DES MARAIS              AGENCE POSTALE COMMUNALE
# 1               12 PLACE DES TOULEUSES  TABAC LES TOULEUSES CC LES TOULEUSES
# 2                    14 RUE RAOUL DUFY                                   NaN
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/pharmacies.parquet")
df.head(10)
# Out:
#   nofinesset nofinessej                                 rs rslongue  \
# 0  750009193  750009185              PHARMACIE MONTORGUEIL      NaN
# 1  750009862  750009854                     PHARM CROULARD      NaN
# 2  750013641  750013633  SELARL PHARMACIE BOSQUET GRENELLE      NaN
# 3  750015240  750015232         PHARM MARBEUF FRANCOIS 1ER      NaN
# 4  750015547  750015521                 PHARMACIE ISSOULIE      NaN
# 5  750015513  750015505      SELAS GRANDE PHARMACIE BAILLY      NaN
# 6  750018046  750018020     PHARMACIE CENTRALE LOUIS BLANC      NaN
# 7  750018574  750018566                PHARMACIE COURONNES      NaN
# 8  750018731  750018723                 PHARMACIE CHAUVEAU      NaN
# 9  750024986  750024960                   PHARMACIE RENOIR      NaN
#
#                       complrs  numvoie compvoie    typvoie               voie  \
# 0                         NaN       67      NaN        RUE        MONTORGUEIL
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/plan de voirie.parquet")
df.head(10)
# Out:
#    OBJECTID NUM_PAVE  IGDS_LEVEL  LIB_LEVEL LIB_CLASSE  \
# 0    201825     133G          21  TRANSPORT        NaN
# 1    201854     151G          21  TRANSPORT        NaN
# 2    201894     193J          21  TRANSPORT        NaN
# 3    201897     154C          21  TRANSPORT        NaN
# 4    201903     173B          21  TRANSPORT        NaN
# 5    201904     173B          21  TRANSPORT        NaN
# 6    201912     142C          21  TRANSPORT        NaN
# 7    201922     184B          21  TRANSPORT        NaN
# 8    201929     184B          21  TRANSPORT        NaN
# 9    201944     163E          21  TRANSPORT        NaN
#
#                                            geo_shape  \
# 0  {"coordinates": [[2.355696017000305, 48.820648...
# 1  {"coordinates": [[2.2925539116883042, 48.83081...
# 2  {"coordinates": [[2.405373885476651, 48.877921...
# 3  {"coordinates": [[2.279349104077107, 48.835857...
# 4  {"coordinates": [[2.3126839621584003, 48.89402...
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/postes-publics-des-bibliotheques.parquet")
df.head(10)
# Out:
#                    localisation             type_de_poste  \
# 0                        Amélie  Poste Adulte et Jeunesse
# 1               Benjamin Rabier   Poste de passage Adulte
# 2              Georges Brassens   Poste de passage Adulte
# 3              Germaine Tillion              Poste Adulte
# 4                      Vandamme            Poste Jeunesse
# 5                        Buffon   Poste de passage Adulte
# 6                        Drouot                 Catalogue
# 7  Glacière - Marina Tsvetaïeva                 Catalogue
# 8                 Louise Michel  Poste Adulte et Jeunesse
# 9              Germaine Tillion            Poste Jeunesse
#
#    nombre_d_ordinateurs                                           position
# 0                     2  b'\x01\x01\x00\x00\x00\xf9\xdcd\xaf\xd2x\x02@\...
# 1                     1  b'\x01\x01\x00\x00\x00\x15\xad\xdc\x0b\xcc\xfa...
# 2                     2  b'\x01\x01\x00\x00\x00\xc9"\xa8uv\x9d\x02@\xce...
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/secteurs-scolaires-colleges.parquet")
df.head(10)
# Out:
#                              id_projet           libelle annee_scol  \
# 0  COLLEGES (année scolaire 2020/2021)      AIME CESAIRE  2020-2021
# 1  COLLEGES (année scolaire 2020/2021)            MOZART  2020-2021
# 2  COLLEGES (année scolaire 2020/2021)    GUILLAUME BUDE  2020-2021
# 3  COLLEGES (année scolaire 2020/2021)      CESAR FRANCK  2020-2021
# 4  COLLEGES (année scolaire 2020/2021)  HONORE DE BALZAC  2020-2021
# 5  COLLEGES (année scolaire 2021/2022)    SONIA DELAUNAY  2021-2022
# 6  COLLEGES (année scolaire 2021/2022)             VALMY  2021-2022
# 7  COLLEGES (année scolaire 2022/2023)      VICTOR DURUY  2022-2023
# 8  COLLEGES (année scolaire 2022/2023)           CHAPTAL  2022-2023
# 9  COLLEGES (année scolaire 2022/2023)    GEORGES BRAQUE  2022-2023
#
#    zone_commune                            etiquette        lib_etab_1  \
# 0             0      Secteur du collège AIME CESAIRE      AIME CESAIRE
# 1             0            Secteur du collège MOZART            MOZART
# ...

# %%
import pandas as pd

df = pd.read_parquet(r"./raw/secteurs-scolaires-maternelles.parquet")
df.head(10)
# Out:
#                                 id_projet                     libelle  \
# 0  MATERNELLES (année scolaire 2020/2021)           BIDASSOA (21) MAT
# 1  MATERNELLES (année scolaire 2020/2021)         JEAN MENANS (2) MAT
# 2  MATERNELLES (année scolaire 2020/2021)          ROQUETTE (144) MAT
# 3  MATERNELLES (année scolaire 2020/2021)               PERLE (7) MAT
# 4  MATERNELLES (année scolaire 2020/2021)       JEANNE D'ARC (32) MAT
# 5  MATERNELLES (année scolaire 2020/2021)             PAJOL (11) POLY
# 6  MATERNELLES (année scolaire 2020/2021)            ALESIA (190) MAT
# 7  MATERNELLES (année scolaire 2020/2021)               RAPP (28) MAT
# 8  MATERNELLES (année scolaire 2020/2021)          PERCHAMPS (38) MAT
# 9  MATERNELLES (année scolaire 2020/2021)  ECLUSES ST MARTIN (28) MAT
#
#   annee_scol  zone_commune                                          etiquette  \
# 0  2020-2021             0           Secteur de l'école 21 RUE DE LA BIDASSOA
# ...
